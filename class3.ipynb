# %%
n = int(input("enter the num"))
s = 0
for i in range(1,n + 1):
    s += i
print(s)
# Out:
# 55

# %%
n = 1
while n != 0:
    n = int(input("enter 0 to exit :"))
    if n != 0:
        print("not 0 , try again")

print("exited!!")
# Out:
# not 0 , try again
# not 0 , try again
# not 0 , try again
# not 0 , try again
# not 0 , try again
# exited!!

# %%
n = 50

while  True:
    i = int(input("enter  a number "))

    if i < n:
        print("low")
    elif i > n:
        print("high")
    else:
        print("Found")
        break
# Out:
# low
# low
# high
# high
# high
# Found

# %%
while True:
    n = int(input("eneter a num"))
    if n > 50:
        print("num is greater than 50, exiting")
        break
# Out:
# num is greater than 50, exiting

# %%
o = 0




while True:
    n = int(input("select operation 1.Add,2.subtract,3.multiplication,4.Division,0.Exit"))
    if n == 0:
        break
    if n not in [1,2,3,4]:
        print("not valid !")
        break
    a = int(input("Enter 1 st number"))
    b = int(input("Enter 2 nd number"))
    if n == 1:
        o = a + b
        print(o)
    elif n == 2:
        o = a - b
        print(o)
    elif n == 3:
        o = a * b
        print(o)
    elif n == 4:
        if b == 0:
            print('cant with 0')
        else:
            o = a / b
            print(o)
print("exited !")
# Out:
# 4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 7
#       3
#       4
#       5
#       6 while True:
# ----> 7     n = int(input("select operation 1.Add,2.subtract,3.multiplication,4.Division,0.Exit"))
#       8     if n == 0:
#       9         break
#      10     if n not in [1,2,3,4]:
#
# ValueError: invalid literal for int() with base 10: ''

# %%
n = int(input("enter a num"))
if n in range(1,101):
    print("within 100")
else:
    print("not in 1 - 100")
# Out:
# not in 1 -100

# %%
n = input("enter a cahrector")
if n == int(n):
    print("integer")

# %%
a = int(input("enter 1 st angle"))
b = int(input("enter 2nd angle"))
c = int(input("enter 3rd angle"))

t = a + b + c

if t == 180 and a > 0 and b > o and c > 0:
    print("is a triangle")
else:
    print("not a triangle")
# Out:
# not a triangle

# %%
a = float(input("Enter length of side 1: "))
b = float(input("Enter length of side 2: "))
c = float(input("Enter length of side 3: "))

if (a + b > c) and (a + c > b) and (b + c > a) and (a > 0 and b > 0 and c > 0):
    if a == b == c:
        print("Equilateral Triangle (All sides are equal)")
    elif a == b or b == c or a == c:
        print("Isosceles Triangle (Two sides are equal)")
    else:
        print("Scalene ")
else:
    print("Invalid side lengths! These sides cannot form a triangle.")

# %%
day = int(input("Enter day: "))
month = int(input("Enter month: "))
year = int(input("Enter year: "))


is_leap = False
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    is_leap = True


if month == 2:
    max_days = 29 if is_leap else 28
elif month in [4, 6, 9, 11]: 
    max_days = 30
else:
    max_days = 31


if year < 1:
    print("Invalid Date (Year must be greater than 0)")
elif month < 1 or month > 12:
    print("Invalid Date (Month must be between 1 and 12)")
elif day < 1 or day > max_days:
    print(f"Invalid Date (Day must be between 1 and {max_days} for month {month})")
else:
    print("Valid Date")
