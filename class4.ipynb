# %%
w = "banana"
n = [ ]
def vow():
    for i in w:
        if i not in ['a','e','i','o','u' ]:
            n.append(i)
    print(n) 
vow()
# Out:
# ['b', 'n', 'n']

# %%
b = []
def odd ():
    for i in range(10):
        if i % 2 != 0:
            if i > 7:
                break
            b.append(i)
    print(b)
odd()
# Out:
# [1, 3, 5, 7]

# %%
s ="not now"
def cnt():
    count = 0
    for ch in s:
        if ch != " ":
            count +=1
    return count
counted = cnt()
print(counted)
# Out:
# 6

# %%
l = ["abcdef","abcd","abc","ghijkmn"]
a = list(filter(lambda x : len(x) >= 5,l))
print(a)
# Out:
# ['abcdef', 'ghijkmn']
