# %%
def evod ():
    x = int(input("enter a num"))
    print( "even" if x % 2 == 0 else "odd")

evod()
# Out:
# odd

# %%
def aded():
    x = int(input("1 st num"))
    y = int(input("2 nd num"))
    print(x + y)
aded ()
# Out:
# 50

# %%
def fa(n):
   
    if n <= 1:
        return 1
    else:
        return n * fa(n - 1)
num = int(input("number"))
print(fa(num))
# Out:
# 120

# %%
li = [ 10 , 20 , 5 , 60 , 9 , 8 , 11 ,3 ,15 ,1]
li2 = list(filter(lambda x : x >= 10,li ))
print(li2)
# Out:
# [10, 20, 60, 11, 15]

# %%
li = []
for i in range (1,100):
    if i % 3 == 0 and i % 5 == 0:
            print("FizzBuuzz")
    elif i % 3 == 0:
        print("Fizz")
    elif i % 5 == 0:
        print("Buzz")
    else:
         print(i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz

# %%
x = int(input("1 num"))
y = int(input("2 num"))
z = int(input("3 num"))

ma = x if x > y and x > z else (y if y >= z else z) 
print(ma)
# Out:
# 30
