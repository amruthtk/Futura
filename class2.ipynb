# %%
#2
cg = float(input("enter ur cgpa"))

status = "eligible" if cg >= 7.5 else "not eligible"
print(status)
# Out:
# not eli

# %%
#3
age = int(input("enter ur age"))

status = "eligible" if age >= 18 else "not eligible"
print(status)
# Out:
# not eli

# %%
#4
n = int(input("enter a num"))

if n % 3 == 0 & n % 5 == 0:
    print("divisible by both 3 and 5")
else:
    print("not")
# Out:
# not

# %%
#5
n = input("enter a char")

if n == n.upper() :
    print("uppercase")
else:
    print("lowercase")
# Out:
# lowercase

# %%
#7
a = int(input("enter 1 num"))
b = int(input("enter 2 num"))

if a > b:
    print(a,"is greater")
else:
    print(b,"is greater")
# Out:
# 50 is greater

# %%
#8
yr = int(input("Enter a year: "))

if (yr % 400 == 0) or (yr % 4 == 0 and yr % 100 != 0):
    print("Leap year")
else:
    print("Not a leap year")
# Out:
# Leap year

# %%
#9
b = int(input("enter a num"))

if  b % 7 == 0:
    print(b,"is divisible by 7")
else:
    print("Not ")
# Out:
# Not

# %%
#12
n = int(input("enter a num 1 -7"))

if n == 1:
    print("monday")
elif n == 2:
    print("tuesday")
elif n == 3:
    print("wednesday")
elif n == 4:
    print("thursday")
elif n == 5:
    print("friday")
elif n == 6:
    print("saturday")
elif n == 7:
    print("sunday")
else:
    print ("invalid Number")
# Out:
# invalid Number

# %%
#14
x = int(input("enter the experience"))

if x > 10:
    print("bonus = 10000")
elif x > 5:
    print("bonus = 5000")
else:
    print ("bonus = 2000")
# Out:
# bonus = 2000

# %%
#15

n = float(input("enter BMi"))

if n >= 30:
    print("obese")
elif n >= 25:
    print("overweight")
elif n >= 18.5:
    print("normal")
else:
    print("underweight")
# Out:
# underweight

# %%
#18
age = int(input("enter age"))
sal = int(input("salary"))

if age >= 21 :
    if sal >= 30000:
        print("eligible")
    else:
        print("not enough salary")
else:
    print("underage")
# Out:
# not enough salary

# %%
mark = int(input("enter marks"))
inc = int(input("salary"))

if mark >= 85:
    if inc < 300000:
        print("eligible")
    else:
        print("not eligivble")
else:
    print("not eligivble")
# Out:
# not eligivble
